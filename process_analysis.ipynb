# %% [markdown]
# # Show a simple process being modelled

# %%
import sys, pkgutil, subprocess, sys
def pipi(*args): subprocess.check_call(["uv", *args])

# Must-haves:
pipi("add", "-q", "ipywidgets>=8.1.0", "anywidget>=0.9.0", "jupyterlab_widgets>=3.0.10")

import ipywidgets as W, anywidget, jupyterlab_widgets
print("ipywidgets:", W.__version__)
print("anywidget:", anywidget.__version__)
import importlib.util
print("has @jupyter-widgets/base via ipywidgets v8 protocol ✔️")
# Out:
# ipywidgets: 8.1.7
# anywidget: 0.9.18
# has @jupyter-widgets/base via ipywidgets v8 protocol ✔️

# %%
import ipywidgets as W
W.Button(description="If you see me, widgets are local ✅")
# Out:
# Button(description='If you see me, widgets are local ✅', style=ButtonStyle())

# %%
from core.visualizers.notebook_visualizers import ProcessViewerWidget, install_vendor_assets


from IPython.display import display

install_vendor_assets()

# --- BPMN example ---
bpmn_xml = """<?xml version="1.0" encoding="UTF-8"?>
<definitions xmlns="http://www.omg.org/spec/BPMN/20100524/MODEL"
             xmlns:bpmndi="http://www.omg.org/spec/BPMN/20100524/DI"
             xmlns:omgdc="http://www.omg.org/spec/DD/20100524/DC"
             xmlns:omgdi="http://www.omg.org/spec/DD/20100524/DI"
             targetNamespace="http://bpmn.io/schema/bpmn">
  <process id="P" isExecutable="false">
    <startEvent id="StartEvent_1"/>
    <task id="Task_123" name="Do Thing"/>
    <sequenceFlow id="Flow_1" sourceRef="StartEvent_1" targetRef="Task_123"/>
  </process>
  <bpmndi:BPMNDiagram>
    <bpmndi:BPMNPlane bpmnElement="P">
      <bpmndi:BPMNShape bpmnElement="StartEvent_1"><omgdc:Bounds x="120" y="100" width="36" height="36"/></bpmndi:BPMNShape>
      <bpmndi:BPMNShape bpmnElement="Task_123"><omgdc:Bounds x="200" y="82" width="100" height="72"/></bpmndi:BPMNShape>
      <bpmndi:BPMNEdge bpmnElement="Flow_1">
        <omgdi:waypoint x="156" y="118"/><omgdi:waypoint x="200" y="118"/>
      </bpmndi:BPMNEdge>
    </bpmndi:BPMNPlane>
  </bpmndi:BPMNDiagram>
</definitions>"""

w = ProcessViewerWidget(mode="bpmn", xml=bpmn_xml, height=420, inline_assets=True)  # explicit
display(w)

# Click callback
def on_click(change):
    print("clicked:", change["new"])
w.observe(on_click, names=["clicked_id"])

# Highlight some elements
w.highlight_ids = ["Task_123", "Flow_1"]

w.mode = "bpmn"
# Out:
# Assets ready in: /Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/core/visualizers/vendor
# ProcessViewerWidget(bpmn_css='.bjs-container {\n  --bjs-font-family: Arial, sans-serif;\n\n  --color-grey-225-…

# %%
# Clear highlights later
# w.highlight_ids = []

# --- Switch to DMN (DRD) ---
dmn_xml = """<?xml version="1.0" encoding="UTF-8"?>
<definitions xmlns="https://www.omg.org/spec/DMN/20191111/MODEL/"
             xmlns:dmndi="https://www.omg.org/spec/DMN/20191111/DMNDI/"
             xmlns:dc="http://www.omg.org/spec/DMN/20180521/DC/"
             xmlns:di="http://www.omg.org/spec/DMN/20180521/DI/"
             id="defs" name="sample">
  <decision id="Decision_1" name="Approve?"/>
  <dmndi:DMNDI>
    <dmndi:DMNDiagram>
      <dmndi:DMNShape dmnElementRef="Decision_1">
        <dc:Bounds x="160" y="100" width="180" height="80"/>
      </dmndi:DMNShape>
    </dmndi:DMNDiagram>
  </dmndi:DMNDI>
</definitions>"""

w.mode = "dmn"
w.xml = dmn_xml
w.highlight_ids = ["Decision_1"]  # highlight works on DRD canvas

w = ProcessViewerWidget(mode="dmn", xml=dmn_xml, height=420, inline_assets=True)  # explicit
display(w)
# Out:
# ProcessViewerWidget(bpmn_css='.bjs-container {\n  --bjs-font-family: Arial, sans-serif;\n\n  --color-grey-225-…
