# %%
import marvin

from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider
from SpiffWorkflow.bpmn.parser import BpmnParser, BpmnValidator
import io

from core.bpmn_validator import validate_bpmn_string

import marvin
from pydantic import BaseModel
from typing import Optional
import xml
from result import Result, Ok, Err, is_ok, is_err

# %%
from pydantic import BaseModel


# Define your data structures
class XMLProcessObject(BaseModel):
    content: str
    type: str
    errors: list[str] = []
    warnings: list[str] = []
    
    
provider = OpenAIProvider(base_url='http://localhost:11434/v1', api_key='')
model = OpenAIModel(model_name='qwen3:4b',
                    provider=provider,
)

# %%
simple_process_description ="I take the customer order and pass it to the fulfillment team, then they package the order and ship it to the customer."

# %% [markdown]
# hi
# hi
#
#
# ``` mermaid
# graph LR;
#
#     User --> |description|A[Bob 1]
#     A --> |type|B[Bob 2]
#     User --> |description or answers|B[Bob 2]
#     PreviousRun --> |Current XML|B[Bob 2]
#     B --> |XML Process Object|D{Validation Tool}
#     D --> |Errors and Warnings|B
#     D --> |Validated XML|C[Bob 3]
#     C --> |Process| E[Process analysis tool]
#     E --> |Analysis| C
#     E --> |Refinement Questions| User
#
# ```
#
# ____
#
# Chain of process analysis:
#
# ``` mermaid
# graph LR;
#
# A[XML Text]-->B{XML Parser}
# B --> BErr[Parsing Errors]
# B --> BOut[Parsed XML]
# A1[Process Model Type]--> C{Process Model Parser}
# BOut --> C
# C --> CErr[Parsing Errors]
# C --> COut[Parsed Process Model]
# COut --> D{Process Model Validator}
# D --> DErr[Validation Errors]
# D --> DOut[Validated Process Model]
# DOut --> E{Process Analysis Compiler}
# E --> EErr[Analysis Compilation Errors]
# E --> F[Process Analyzer]
# F --> |Process Analysis|ProcessOpportunityDash[Process Opportunity Dashboard]
# F --> |Process Analysis|Bob4[Process Consultant 4]
# Bob4 -->|Biggest Remaining Questions| User
#
# ______

# %%
import marvin

from pydantic_ai.models.openai import OpenAIModel
from pydantic_ai.providers.openai import OpenAIProvider

provider = OpenAIProvider(base_url='http://localhost:11434/v1', api_key='')
model = OpenAIModel(model_name='qwen3:4b',
                    provider=provider,
)




# show that bob 1 works
bob_1 = marvin.Agent(name="Bob_1", model=model, model_settings={'think':False},
                   instructions="""What kind of process is this? BPMN, DMN or CMMN? don't explain your reasoning.""",)


answer = bob_1.run(simple_process_description, handlers=[])

print(answer)

assert answer == "BPMN"
# Out:
# [08/20/25 12:50:47] ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=104072;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=872272;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartStartEvent: list index out of range
# [08/20/25 12:50:48] ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=332010;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=63392;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=57291;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=377745;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartStartEvent: list index out of range
# BPMN

# %%
EMPTY_XML_TEMPLATES_MINIMAL = {
    "BPMN": """<?xml version="1.0" encoding="UTF-8"?>
<bpmn:definitions id="{definitions_id}" targetNamespace="{target_namespace}"
  xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
  xmlns:bpmn="http://www.omg.org/spec/BPMN/20100524/MODEL"
  xmlns:bpmndi="http://www.omg.org/spec/BPMN/20100524/DI"
  xmlns:dc="http://www.omg.org/spec/DD/20100524/DC"
  xmlns:di="http://www.omg.org/spec/DD/20100524/DI">
  <!-- Add <bpmn:process>, <bpmn:collaboration>, etc. later -->
</bpmn:definitions>
""",

    "DMN": """<?xml version="1.0" encoding="UTF-8"?>
<definitions id="{definitions_id}" name="{definitions_name}" namespace="{target_namespace}"
  xmlns="https://www.omg.org/spec/DMN/20191111/MODEL/"
  xmlns:dmndi="https://www.omg.org/spec/DMN/20191111/DMNDI/"
  xmlns:di="http://www.omg.org/spec/DMN/20180521/DI/"
  xmlns:dc="http://www.omg.org/spec/DMN/20180521/DC/"
  xmlns:feel="https://www.omg.org/spec/DMN/20191111/FEEL/">
  <!-- Add <decision>, <inputData>, <businessKnowledgeModel>, etc. later -->
</definitions>
""",

    "CMMN": """<?xml version="1.0" encoding="UTF-8"?>
<cmmn:definitions id="{definitions_id}" targetNamespace="{target_namespace}"
  xmlns:cmmn="http://www.omg.org/spec/CMMN/20151109/MODEL"
  xmlns:cmmndi="http://www.omg.org/spec/CMMN/20151109/CMMNDI"
  xmlns:dc="http://www.omg.org/spec/DD/20100524/DC"
  xmlns:di="http://www.omg.org/spec/DD/20100524/DI">
  <!-- Add <cmmn:case> later -->
</cmmn:definitions>
""",

    "ArchiMate": """<?xml version="1.0" encoding="UTF-8"?>
<model xmlns="http://www.opengroup.org/xsd/archimate/3.0/"
  xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance"
  identifier="{model_id}" name="{model_name}">
  <metadata>
    <schema>{schema_version}</schema>
  </metadata>
  <!-- Add <elements>, <relationships>, <organizations>, <properties> later -->
</model>
""",
}

# (Optional) Example of just the global setup values you might pass:
EXAMPLE_GLOBAL_INPUTS = {
    "BPMN": {
        "definitions_id": "def_bpmn_empty",
        "target_namespace": "urn:example:bpmn",
    },
    "DMN": {
        "definitions_id": "def_dmn_empty",
        "definitions_name": "EmptyDMN",
        "target_namespace": "urn:example:dmn",
    },
    "CMMN": {
        "definitions_id": "def_cmmn_empty",
        "target_namespace": "urn:example:cmmn",
    },
    "ArchiMate": {
        "model_id": "archi_model_empty",
        "model_name": "EmptyModel",
        "schema_version": "3.0",
    },
}

# Render one (example):
# EMPTY_XML_TEMPLATES_MINIMAL["BPMN"].format(**EXAMPLE_GLOBAL_INPUTS["BPMN"])


def get_empty_process_model(model_type):
    if model_type not in EMPTY_XML_TEMPLATES_MINIMAL:
        raise ValueError(f"Unknown model type: {model_type}")
    return EMPTY_XML_TEMPLATES_MINIMAL[model_type], EXAMPLE_GLOBAL_INPUTS[model_type]

# %%
# show getting the empty process model
empty_proc, examples = get_empty_process_model(answer)

# %%
#show bob2 at work 

bob_2 = marvin.Agent(name="Bob_2", model=model, model_settings={'think':False},
                   instructions="""You are an expert business process modelling consultant. Your job is to look at \
                       a current XML diagram of a business process, along with a english language description of a business process\
                       and to output a new, valid XML diagram that reflects the business process described.""",
                     tools=[validate_bpmn_string])




t1 = marvin.Task('Make the necessary changes to the XML diagram to align it with the described business process', agents=[bob_2],
            context={"description": simple_process_description, "xml_process": empty_proc},
)

# %%
output = t1.run(handlers=[])
# Out:
# [08/20/25 11:05:25] ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=224047;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=766272;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartStartEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=902826;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=998752;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=576031;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=339541;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=675322;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=358415;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=743421;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=457998;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=181459;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=70908;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=505899;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=559984;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=439552;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=760564;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=729664;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=24889;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=696119;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=145200;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=657849;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=936601;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=962092;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=594780;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=359697;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=111200;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=18887;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=898771;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=398898;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=886296;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=562542;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=897974;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
# [08/20/25 11:05:26] ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=324028;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=319349;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=924036;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=648479;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=507990;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=40233;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=63032;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=885066;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=237828;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=80674;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=375309;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=22698;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=331945;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=100070;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=593853;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=818264;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=518410;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=118267;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=299838;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=507426;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=982526;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=931140;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=964035;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=646096;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=112740;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=407052;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=525001;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=450916;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=140579;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=95094;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=600759;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=529264;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=194676;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=554000;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=778451;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=298535;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=115249;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=944606;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=733905;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=529623;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=999195;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=46768;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=566187;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=391666;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=678720;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=119466;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=939655;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=366665;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=781160;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=383860;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=509968;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=385424;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=742633;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=3961;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=878253;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=161768;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=312336;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=245994;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=516561;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=871016;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=853504;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=636077;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=111222;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=413214;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=229938;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=561159;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=618108;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=270970;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=908091;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=699836;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=241676;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=595548;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=153205;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=842698;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=831525;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=289857;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=745645;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=304718;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=218893;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=522361;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=812320;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=264458;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=65322;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=659131;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=64351;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=758123;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
# [08/20/25 11:05:27] ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=410310;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=92545;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=634214;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=202252;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=828007;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=532039;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=805004;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=95292;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=383410;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=124369;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=36858;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=443626;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=348229;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=339291;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=539775;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=413963;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=502758;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=233664;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=391057;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=673659;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=316769;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=393024;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=420830;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=816254;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=245117;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=86737;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=625993;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=750461;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=116054;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=734006;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=957136;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=454213;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=387186;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=208606;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=853842;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=115110;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=659609;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=707569;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=22060;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=720787;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=82435;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=933526;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=185583;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=47385;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=564342;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=677058;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=352948;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=664204;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=16947;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=388740;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=393214;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=678435;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=812130;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=744076;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=147378;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=950064;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=516738;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=460190;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=416166;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=90901;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=62666;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=854308;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=737032;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=741236;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=221197;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=370203;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=485900;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=911877;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=958791;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=394326;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=483735;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=810822;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=23221;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=113245;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=187001;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=681044;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=107432;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=270153;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=718226;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=595698;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=866660;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=917181;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=460060;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=610327;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
# ...
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=826626;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=100849;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=784997;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=421310;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=886281;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=59866;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=228940;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=73052;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=344827;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=899948;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=678234;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=674262;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=418325;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=453282;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=286638;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=960664;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=344166;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=353650;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=320999;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=458859;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=670754;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=279909;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=56789;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=95908;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=595983;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=799316;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=377083;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=423111;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=416456;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=837241;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
#                     ERROR    marvin.engine.streaming: Error processing pydantic event              ]8;id=364153;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py\streaming.py]8;;\:]8;id=678709;file:///Users/marshallomoore/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py#126\126]8;;\
#                              PartDeltaEvent: list index out of range
# ---------------------------------------------------------------------------
# ToolRetryError                            Traceback (most recent call last)
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/pydantic_ai/_agent_graph.py:552, in CallToolsNode._handle_text_response(self, ctx, texts)
#     549     m = _messages.RetryPromptPart(
#     550         content='Plain text responses are not permitted, please include your response in a tool call',
#     551     )
# --> 552     raise ToolRetryError(m)
#     554 for validator in ctx.deps.output_validators:
#
# ToolRetryError:
#
# The above exception was the direct cause of the following exception:
#
# UnexpectedModelBehavior                   Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 output = t1.run(handlers=[])
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/tasks/task.py:494, in Task.run(self, thread, raise_on_failure, handlers)
#     487 def run(
#     488     self,
#     489     *,
#    (...)    492     handlers: list["Handler | AsyncHandler"] | None = None,
#     493 ) -> T:
# --> 494     return run_sync(
#     495         self.run_async(
#     496             thread=thread, raise_on_failure=raise_on_failure, handlers=handlers
#     497         ),
#     498     )
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/utilities/asyncio.py:45, in run_sync(coro)
#      43 except RuntimeError as e:
#      44     if "event loop" in str(e):
# ---> 45         return run_sync_in_thread(coro)
#      46     raise e
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/utilities/asyncio.py:94, in run_sync_in_thread(coro)
#      91 done.wait()
#      93 if error is not None:
# ---> 94     raise error
#      96 return result
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/utilities/asyncio.py:81, in run_sync_in_thread.<locals>.thread_target()
#      79 try:
#      80     asyncio.set_event_loop(loop)
# ---> 81     result = ctx.run(loop.run_until_complete, coro)
#      82 except BaseException as e:
#      83     error = e
#
# File /opt/anaconda3/lib/python3.12/asyncio/base_events.py:687, in BaseEventLoop.run_until_complete(self, future)
#     684 if not future.done():
#     685     raise RuntimeError('Event loop stopped before Future completed.')
# --> 687 return future.result()
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/tasks/task.py:479, in Task.run_async(self, thread, raise_on_failure, handlers)
#     472 async def run_async(
#     473     self,
#     474     *,
#    (...)    477     handlers: list["Handler | AsyncHandler"] | None = None,
#     478 ) -> T:
# --> 479     await marvin.fns.run.run_tasks_async(
#     480         [self],
#     481         thread=thread,
#     482         raise_on_failure=raise_on_failure,
#     483         handlers=handlers,
#     484     )
#     485     return self.result
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/fns/run.py:29, in run_tasks_async(tasks, thread, raise_on_failure, handlers)
#      18 async def run_tasks_async(
#      19     tasks: list[Task[Any]],
#      20     thread: Thread | str | None = None,
#      21     raise_on_failure: bool = True,
#      22     handlers: list[Handler | AsyncHandler] | None = None,
#      23 ) -> list[Task[Any]] | AsyncGenerator[Event, None]:
#      24     orchestrator = Orchestrator(
#      25         tasks=tasks,
#      26         thread=thread,
#      27         handlers=handlers,
#      28     )
# ---> 29     await orchestrator.run(raise_on_failure=raise_on_failure)
#      30     return tasks
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/orchestrator.py:263, in Orchestrator.run(self, raise_on_failure, max_turns)
#     252 # the while loop continues until all the tasks that were
#     253 # provided to the orchestrator are complete OR max turns is
#     254 # reached. Note this is not the same as checking *every*
#    (...)    257 # the orchestrator logic, but not considered part of the
#     258 # termination condition.
#     259 while incomplete_tasks and (
#     260     max_turns is None or turns < max_turns
#     261 ):
#     262     # Pass active_mcp_servers to run_once
# --> 263     result = await self.run_once(
#     264         actor=actor, active_mcp_servers=active_mcp_servers
#     265     )
#     266     results.append(result)
#     267     turns += 1
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/orchestrator.py:184, in Orchestrator.run_once(self, actor, active_mcp_servers)
#     179 with actor:
#     180     async with agentlet.iter(
#     181         user_prompt,
#     182         message_history=[m.message for m in prompt_messages],
#     183     ) as run:
# --> 184         async for event in handle_agentlet_events(
#     185             agentlet=agentlet,
#     186             actor=actor,
#     187             run=run,
#     188         ):
#     189             await self.handle_event(event)
#     191 # --- add final messages to the thread
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/marvin/engine/streaming.py:136, in handle_agentlet_events(agentlet, actor, run)
#     133 elif pydantic_ai.Agent.is_call_tools_node(node):
#     134     # Handle-response node - the model returned data, potentially calls a tool
#     135     async with node.stream(run.ctx) as handle_stream:
# --> 136         async for event in handle_stream:
#     137             try:
#     138                 event = _process_pydantic_event(
#     139                     event=event,
#     140                     actor=actor,
#    (...)    143                     end_turn_tools_map=end_turn_tools_map,
#     144                 )
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/pydantic_ai/_agent_graph.py:488, in CallToolsNode._run_stream(self, ctx)
#     484             raise exceptions.UnexpectedModelBehavior('Received empty model response')
#     486     self._events_iterator = _run_stream()
# --> 488 async for event in self._events_iterator:
#     489     yield event
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/pydantic_ai/_agent_graph.py:460, in CallToolsNode._run_stream.<locals>._run_stream()
#     457         yield event
#     458 elif texts:
#     459     # No events are emitted during the handling of text responses, so we don't need to yield anything
# --> 460     self._next_node = await self._handle_text_response(ctx, texts)
#     461 elif thinking_parts:
#     462     # handle thinking-only responses (responses that contain only ThinkingPart instances)
#     463     # this can happen with models that support thinking mode when they don't provide
#     464     # actionable output alongside their thinking content.
#     465     self._next_node = ModelRequestNode[DepsT, NodeRunEndT](
#     466         _messages.ModelRequest(
#     467             parts=[_messages.RetryPromptPart('Responses without text or tool calls are not permitted.')]
#     468         )
#     469     )
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/pydantic_ai/_agent_graph.py:557, in CallToolsNode._handle_text_response(self, ctx, texts)
#     555         result_data = await validator.validate(result_data, run_context)
#     556 except ToolRetryError as e:
# --> 557     ctx.state.increment_retries(ctx.deps.max_result_retries, e)
#     558     return ModelRequestNode[DepsT, NodeRunEndT](_messages.ModelRequest(parts=[e.tool_retry]))
#     559 else:
#
# File ~/Desktop/ProjectsLocal/AgenticBobs/.venv/lib/python3.12/site-packages/pydantic_ai/_agent_graph.py:90, in GraphAgentState.increment_retries(self, max_result_retries, error)
#      88     if isinstance(error, exceptions.UnexpectedModelBehavior) and error.__cause__ is not None:
#      89         error = error.__cause__
# ---> 90     raise exceptions.UnexpectedModelBehavior(message) from error
#      91 else:
#      92     raise exceptions.UnexpectedModelBehavior(message)
#
# UnexpectedModelBehavior: Exceeded maximum retries (1) for output validation

# %%
print(output)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <bpmn:definitions id="process_definitions" targetNamespace="http://example.com/processes" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:bpmn="http://www.omg.org/spec/BPMN/20100524/MODEL">
#   <bpmn:process id="process_1" name="Order Fulfillment Process">
#     <bpmn:startEvent id="start_event_1" name="Customer Order Received"/>
#     <bpmn:task id="task_1" name="Pass order to fulfillment team"/>
#     <bpmn:task id="task_2" name="Package order"/>
#     <bpmn:task id="task_3" name="Ship order to customer"/>
#     <bpmn:endEvent id="end_event_1" name="Order Shipped"/>
#     <bpmn:sequenceFlow id="flow_1" sourceRef="start_event_1" targetRef="task_1"/>
#     <bpmn:sequenceFlow id="flow_2" sourceRef="task_1" targetRef="task_2"/>
#     <bpmn:sequenceFlow id="flow_3" sourceRef="task_2" targetRef="task_3"/>
#     <bpmn:sequenceFlow id="flow_4" sourceRef="task_3" targetRef="end_event_1"/>
#   </bpmn:process>
# </bpmn:definitions>

# %%
valid = BpmnValidator()

parser = BpmnParser(validator=valid)

bytes_xml = output.encode("UTF-8")
bytes_io = io.BytesIO(bytes_xml)
parser.add_bpmn_io(bytes_io)

# %%
# Define your data structures
class XMLProcessObject(BaseModel):
    content: str
    type: str
    errors: list[str] = []
    warnings: list[str] = []
    
    
provider = OpenAIProvider(base_url='http://localhost:11434/v1', api_key='')
model = OpenAIModel(model_name='qwen3:4b',
                    provider=provider,
)


    
bob_1 = marvin.Agent(name="Bob_1", model=model, model_settings={'think':False},
                   instructions="""You are a expert business process modelling consultant. Your job is to look \
                       at at a business process and decide if it is best modelled as BPMN, DMN or CMMN. Please just\
                    respond with the appropriate model type, no explaination is needed.""")


bob_2 = marvin.Agent(name="Bob_2", model=model, model_settings={'think':False},
                   instructions="""You are an expert business process modelling consultant. Your job is to look at \
                       a current XML diagram of a business process, along with a english language description of a business process\
                       and to output required changes to the XML diagram to better align it with the described process.""")


# Create specialized agents
bob1 = marvin.Agent(
    name="Bob 1",
    instructions="Convert user descriptions into process types"
)

bob2 = marvin.Agent(
    name="Bob 2", 
    instructions="Generate XML Process Objects from descriptions and types"
)

bob3 = marvin.Agent(
    name="Bob 3",
    instructions="Perform process analysis and generate refinement questions"
)

# Create validation tool
def validation_tool(xml_obj: XMLProcessObject) -> XMLProcessObject:
    """Validate XML Process Object and return errors/warnings"""
    # Your validation logic here
    validated_obj = xml_obj.model_copy()
    # Add validation results
    return validated_obj

def process_analysis_tool(xml_obj: XMLProcessObject) -> dict:
    """Analyze the process and return analysis results"""
    # Your analysis logic here
    return {"analysis": "Process analysis results"}





with marvin.Thread() as thread:
    # Check if process type exists in thread context
    if not hasattr(thread, '_process_type'):
        thread._process_type = marvin.run(
            "Convert description to process type",
            agents=[bob1],
            context = {"description": simple_process_description},
            thread=thread
        )
        
        
    if not hasattr(thread, '_xml_process'):
        thread._xml_process, example_inputs = get_empty_process_model(thread._process_type, EMPTY_XML_TEMPLATES_MINIMAL)

    # Use the cached process type
    xml_process = marvin.run(
        "Generate XML Process Object", 
        agents=[bob2],
        context={"type": thread._process_type},
        thread=thread
    )
    
    # Step 3: Validation loop (Bob 2 can retry based on validation)
    while xml_process.errors:
        xml_process = marvin.run(
            "Fix XML Process Object based on validation errors",
            agents=[bob2],
            result_type=XMLProcessObject,
            tools=[validation_tool],
            context={"errors": xml_process.errors},
            thread=thread
        )
    
    # Step 4: Bob 3 performs analysis
    analysis = marvin.run(
        "Analyze the validated XML process",
        agents=[bob3],
        tools=[process_analysis_tool],
        context={"xml_process": xml_process},
        thread=thread
    )
    
    # Step 5: Generate refinement questions for user
    questions = marvin.run(
        "Generate refinement questions based on analysis",
        agents=[bob3],
        result_type=list[str],
        context={"analysis": analysis},
        cli=True,  # Enable CLI interaction with user
        thread=thread
    )
